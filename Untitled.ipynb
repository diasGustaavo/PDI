# %%
import numpy as np
import pandas as pd
import cv2 as cv
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
import pathlib

# %%
dirAtual = str(pathlib.Path().absolute())

# %%
def convertToYIQ(rgbImage):
    for item in image:
        for item2 in item:
            print(item2)
            Y = (0.299*item2[0]) + (0.5876*item2[1]) + (0.114*item2[2])
            I = (0.596*item2[0]) - (0.2746*item2[1]) - (0.322*item2[2])
            Q = (0.211*item2[0]) - (0.5236*item2[1]) + (0.312*item2[2])
            item2 = [Y, I, Q]
            print(item2)
            print("cut")
    return(image)

# %%
def teste2(rgbImage):
    return [((0.299*rgbImage[0]) + (0.5876*rgbImage[1]) + (0.114*rgbImage[2])), ((0.596*rgbImage[0]) - (0.2746*rgbImage[1]) - (0.322*rgbImage[2])), ((0.211*rgbImage[0]) - (0.5236*rgbImage[1]) + (0.312*rgbImage[2]))]

# %%
def teste(rgbImage):
    for element in rgbImage:
        #print(element)
        resultado = map(teste2, element)
        element = list(resultado)
        #print(element)
        #print("-------")
    return rgbImage

# %%
image = io.imread(dirAtual + '/Imagens/Woman.png')
plt.imshow(image)
plt.show()
atualizada = teste(image)
atualizada
# Out:
# array([[[  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         ...,
#         [ 10,  13,  20, 255],
#         [ 10,  13,  20, 255],
#         [ 10,  13,  20, 255]],
#
#        [[  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         ...,
#         [ 10,  13,  20, 255],
#         [  4,   8,  12, 255],
#         [  4,   8,  12, 255]],
#
#        [[  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         ...,
#         [  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         [  4,   8,  12, 255]],
#
#        ...,
#
#        [[  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         ...,
#         [ 17,  19,  23, 255],
#         [ 10,  13,  20, 255],
#         [ 17,  19,  23, 255]],
#
#        [[  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         [  4,   8,  12, 255],
#         ...,
#         [ 17,  19,  23, 255],
# ...

# %%
image2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
plt.imshow(image2)
plt.show()
image2
# Out:
# array([[[12,  8,  4],
#         [12,  8,  4],
#         [12,  8,  4],
#         ...,
#         [20, 13, 10],
#         [20, 13, 10],
#         [20, 13, 10]],
#
#        [[12,  8,  4],
#         [12,  8,  4],
#         [12,  8,  4],
#         ...,
#         [20, 13, 10],
#         [12,  8,  4],
#         [12,  8,  4]],
#
#        [[12,  8,  4],
#         [12,  8,  4],
#         [12,  8,  4],
#         ...,
#         [12,  8,  4],
#         [12,  8,  4],
#         [12,  8,  4]],
#
#        ...,
#
#        [[12,  8,  4],
#         [12,  8,  4],
#         [12,  8,  4],
#         ...,
#         [23, 19, 17],
#         [20, 13, 10],
#         [23, 19, 17]],
#
#        [[12,  8,  4],
#         [12,  8,  4],
#         [12,  8,  4],
#         ...,
#         [23, 19, 17],
#         [20, 13, 10],
#         [23, 19, 17]],
#
#        [[12,  8,  4],
#         [12,  8,  4],
#         [12,  8,  4],
#         ...,
#         [23, 19, 17],
#         [20, 13, 10],
#         [20, 13, 10]]], dtype=uint8)
